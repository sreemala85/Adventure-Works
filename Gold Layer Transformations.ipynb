# %% [markdown]
# #Data Access Using App

# %%
spark.conf.set('fs.azure.account.auth.type.<storage-account>.dfs.core.windows.net', 'OAuth')
spark.conf.set('fs.azure.account.oauth.provider.type.<storage-account>.dfs.core.windows.net', 'org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider')
spark.conf.set('fs.azure.account.oauth2.client.id.<storage-account>.dfs.core.windows.net', '<application-id>')
spark.conf.set('fs.azure.account.oauth2.client.secret.<storage-account>.dfs.core.windows.net', 'service credential')
spark.conf.set('fs.azure.account.oauth2.client.endpoint.<storage-account>.dfs.core.windows.net', 'https://login.microsoftonline.com/<directory-id>/oauth2/token')

# %% [markdown]
# **_Create View for Calendar_**

# %%
# %sql
CREATE OR REPLACE VIEW adventure_works.default.Calendar
AS SELECT * FROM read_files(
  'abfss://silver@storagesreemala.dfs.core.windows.net/Calendar',
  format => 'parquet',
  header => true
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# **_Create View for Customer_**

# %%
# %sql
CREATE OR REPLACE VIEW adventure_works.default.Customer
AS SELECT * FROM read_files(
  'abfss://silver@storagesreemala.dfs.core.windows.net/Customer',
  format => 'parquet',
  header => true
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# **_Create View for Product Categories_**

# %%
# %sql
CREATE OR REPLACE VIEW adventure_works.default.Product_Categories
AS SELECT * FROM read_files(
  'abfss://silver@storagesreemala.dfs.core.windows.net/Product_Categories',
  format => 'parquet',
  header => true
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# **_Create View for Product SubCategories_**

# %%
# %sql
CREATE OR REPLACE VIEW adventure_works.default.Product_Subcategories
AS SELECT * FROM read_files(
  'abfss://silver@storagesreemala.dfs.core.windows.net/Product_Subcategories',
  format => 'parquet',
  header => true
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# **_Create View for Products_**

# %%
# %sql
CREATE OR REPLACE VIEW adventure_works.default.Products
AS SELECT * FROM read_files(
  'abfss://silver@storagesreemala.dfs.core.windows.net/Products',
  format => 'parquet',
  header => true
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# **_Create View for Returns_**

# %%
# %sql
CREATE OR REPLACE VIEW adventure_works.default.Returns
AS SELECT * FROM read_files(
  'abfss://silver@storagesreemala.dfs.core.windows.net/Returns',
  format => 'parquet',
  header => true
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# **_Create View for Territories_**

# %%
# %sql
CREATE OR REPLACE VIEW adventure_works.default.Territories
AS SELECT * FROM read_files(
  'abfss://silver@storagesreemala.dfs.core.windows.net/Territories',
  format => 'parquet',
  header => true
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# **_Create View for Sales_**

# %%
# %sql
CREATE OR REPLACE VIEW adventure_works.default.Sales
AS SELECT * FROM read_files(
  'abfss://silver@storagesreemala.dfs.core.windows.net/Sales',
  format => 'parquet',
  header => true
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Number of Daily sales per day

# %%
# %sql
SELECT OrderDate, count(distinct OrderNumber) as Total_Orders
FROM adventure_works.default.Sales
GROUP BY OrderDate;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE adventure_works.default.Sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>OrderDate</td><td>date</td><td>null</td></tr><tr><td>StockDate</td><td>date</td><td>null</td></tr><tr><td>OrderNumber</td><td>string</td><td>null</td></tr><tr><td>ProductKey</td><td>int</td><td>null</td></tr><tr><td>CustomerKey</td><td>int</td><td>null</td></tr><tr><td>TerritoryKey</td><td>int</td><td>null</td></tr><tr><td>OrderLineItem</td><td>int</td><td>null</td></tr><tr><td>OrderQuantity</td><td>int</td><td>null</td></tr><tr><td>_rescued_data</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED adventure_works.default.Sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
